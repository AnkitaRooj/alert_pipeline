# %%
pip install feedparser requests newspaper3k pandas lxml[html_clean]
# Out:
# Requirement already satisfied: feedparser in /usr/local/lib/python3.12/dist-packages (6.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: newspaper3k in /usr/local/lib/python3.12/dist-packages (0.2.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: lxml[html_clean] in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.12/dist-packages (from feedparser) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (4.13.5)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (11.3.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (6.0.3)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (1.3.0)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (3.9.1)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (5.3.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (2.9.0.post0)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (0.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Collecting lxml_html_clean (from lxml[html_clean])
#   Downloading lxml_html_clean-0.4.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (4.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (2025.9.18)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (4.67.1)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.12/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.0.1)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.12/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.20.0)
# Downloading lxml_html_clean-0.4.3-py3-none-any.whl (14 kB)
# Installing collected packages: lxml_html_clean
# Successfully installed lxml_html_clean-0.4.3

# %%
import feedparser
import requests
from newspaper import Article
import pandas as pd
from datetime import datetime, timedelta
import time

class NewsScraper:
    def __init__(self):
        self.feeds = [
            'https://feeds.reuters.com/reuters/businessNews',
            'https://feeds.reuters.com/reuters/mergersNews',
            'https://feeds.reuters.com/reuters/companyNews'
        ]

    def fetch_news_from_feeds(self):
        """Fetch news from RSS feeds"""
        articles = []

        for feed_url in self.feeds:
            try:
                feed = feedparser.parse(feed_url)
                for entry in feed.entries[:10]:  # Get latest 10 articles per feed
                    article_data = {
                        'title': entry.title,
                        'url': entry.link,
                        'published': entry.published if 'published' in entry else '',
                        'source': 'Reuters',
                        'content': ''
                    }

                    # Try to get full content
                    try:
                        article = Article(entry.link)
                        article.download()
                        article.parse()
                        article_data['content'] = article.text
                        article_data['authors'] = article.authors
                        article_data['publish_date'] = article.publish_date
                    except:
                        article_data['content'] = entry.summary if 'summary' in entry else ''

                    articles.append(article_data)
                    time.sleep(0.5)  # Be respectful to servers

            except Exception as e:
                print(f"Error fetching from {feed_url}: {e}")

        return articles

    def get_sample_financial_news(self):
        """Get sample financial news for demonstration"""
        sample_news = [
            {
                'title': 'Microsoft acquires AI startup Lumier for $500 million',
                'content': 'Microsoft Corporation announced today that it has acquired Lumier, an artificial intelligence startup, for approximately $500 million. The acquisition will strengthen Microsoft\'s AI capabilities in the enterprise sector.',
                'url': 'https://example.com/microsoft-lumier',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            },
            {
                'title': 'JPMorgan Chase invests in blockchain company ChainTech',
                'content': 'JPMorgan Chase & Co. has made a strategic investment in ChainTech, a blockchain technology company. The investment is part of JPMorgan\'s ongoing digital transformation initiatives.',
                'url': 'https://example.com/jpmorgan-chaintech',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            },
            {
                'title': 'Google DeepMind partners with pharmaceutical giant',
                'content': 'Google DeepMind has entered into a partnership with a major pharmaceutical company to develop AI-driven drug discovery platforms.',
                'url': 'https://example.com/deepmind-pharma',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            },
            {
                'title': 'Apple reports strong quarterly earnings',
                'content': 'Apple Inc. reported better-than-expected quarterly earnings, driven by strong iPhone sales and services growth.',
                'url': 'https://example.com/apple-earnings',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            }
        ]
        return sample_news

# if __name__ == "__main__":
scraper = NewsScraper()
articles = scraper.fetch_news_from_feeds()
print(f"Fetched {len(articles)} articles")
# Out:
# Fetched 0 articles

# %%
newsapi_key="7372da6867a4469389333127e07e4615"

# %%
import feedparser
import requests
from newspaper import Article
import pandas as pd
from datetime import datetime, timedelta
import time
import random

class NewsScraper:
    def __init__(self):
        # Updated valid RSS feeds for financial news
        self.feeds = [
            # Yahoo Finance RSS feeds
            'https://finance.yahoo.com/news/rssindex',
            'https://feeds.finance.yahoo.com/rss/2.0/headline?s=msft,aapl,goog,jpm,gs&region=US&lang=en-US',

            # MarketWatch RSS
            'http://feeds.marketwatch.com/marketwatch/topstories/',
            'http://feeds.marketwatch.com/marketwatch/marketpulse/',

            # Investing.com RSS
            'https://www.investing.com/rss/news_301.rss',
            'https://www.investing.com/rss/market_overview.rss',

            # CNBC RSS feeds
            'https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000664',  # Top Business News
            'https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=15839135',  # M&A News

            # Bloomberg RSS (markets)
            'https://feeds.bloomberg.com/markets/news.rss',

            # Financial Times (business news)
            'https://www.ft.com/business?format=rss',

            # The Wall Street Journal (business)
            'https://feeds.a.dj.com/rss/RSSWSJD.xml',

            # Business Insider
            'https://markets.businessinsider.com/rss/news',
        ]

        # Set headers to mimic a real browser
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }

    def fetch_news_from_feeds(self):
        """Fetch news from RSS feeds with better error handling"""
        articles = []
        successful_feeds = 0

        for feed_url in self.feeds:
            try:
                print(f"Attempting to fetch from: {feed_url}")

                # Add timeout and custom headers to feedparser
                feed = feedparser.parse(feed_url)

                if hasattr(feed, 'status') and feed.status != 200:
                    print(f"Feed returned status {feed.status} for {feed_url}")
                    continue

                if not feed.entries:
                    print(f"No entries found in feed: {feed_url}")
                    continue

                print(f"✓ Found {len(feed.entries)} entries in {feed_url}")
                successful_feeds += 1

                for entry in feed.entries[:6]:  # Get latest 6 articles per feed
                    try:
                        # Skip if no title
                        if not hasattr(entry, 'title') or not entry.title:
                            continue

                        article_data = {
                            'title': entry.title,
                            'url': entry.link,
                            'published': entry.published if 'published' in entry else datetime.now().isoformat(),
                            'source': self._get_source_name(feed_url),
                            'content': '',
                            'summary': entry.summary if hasattr(entry, 'summary') else ''
                        }

                        # Try to get full content with newspaper3k
                        full_content = self._get_article_content(entry.link)
                        if full_content:
                            article_data['content'] = full_content
                        else:
                            # Fallback to summary
                            article_data['content'] = article_data['summary']

                        # Only add if we have reasonable content
                        if article_data['content'] and len(article_data['content']) > 50:
                            articles.append(article_data)
                            print(f"  ✓ Added: {entry.title[:60]}...")
                        else:
                            print(f"  ⚠ Skipped (insufficient content): {entry.title[:60]}...")

                    except Exception as e:
                        print(f"  Error processing article: {e}")
                        continue

                    time.sleep(0.5)  # Be respectful to servers

            except Exception as e:
                print(f"✗ Error fetching from {feed_url}: {str(e)[:100]}...")
                continue

        print(f"Successfully processed {successful_feeds}/{len(self.feeds)} feeds")
        return articles

    def _get_source_name(self, feed_url):
        """Extract source name from feed URL"""
        source_map = {
            'yahoo': 'Yahoo Finance',
            'marketwatch': 'MarketWatch',
            'investing': 'Investing.com',
            'cnbc': 'CNBC',
            'bloomberg': 'Bloomberg',
            'ft.com': 'Financial Times',
            'dj.com': 'Wall Street Journal',
            'businessinsider': 'Business Insider'
        }

        for key, name in source_map.items():
            if key in feed_url:
                return name
        return 'Financial News'

    def _get_article_content(self, url):
        """Extract full article content using newspaper3k with error handling"""
        try:
            # Create Article object with timeout
            article = Article(url, request_timeout=10)
            article.download()
            article.parse()

            # Return text if we got meaningful content
            if article.text and len(article.text) > 100:
                return article.text
            else:
                return None

        except Exception as e:
            # print(f"Could not extract content from {url}: {e}")  # Commented to reduce noise
            return None

    def fetch_financial_news_api(self):
        """Alternative method using free financial news APIs"""
        articles = []

        # NewsAPI.org (you would need to get a free API key)
        # This is just a template - you'd need to sign up for an API key
        newsapi_key = 'your_api_key_here'  # Get from https://newsapi.org
        if newsapi_key != 'your_api_key_here':
            try:
                url = f'https://newsapi.org/v2/top-headlines?category=business&language=en&apiKey={newsapi_key}'
                response = requests.get(url, timeout=10)
                if response.status_code == 200:
                    data = response.json()
                    for article in data.get('articles', [])[:10]:
                        articles.append({
                            'title': article.get('title', ''),
                            'url': article.get('url', ''),
                            'published': article.get('publishedAt', datetime.now().isoformat()),
                            'source': article.get('source', {}).get('name', 'NewsAPI'),
                            'content': article.get('description', '') + ' ' + article.get('content', ''),
                        })
            except Exception as e:
                print(f"NewsAPI error: {e}")

        return articles

    def get_sample_financial_news(self):
        """Get comprehensive sample financial news for demonstration"""
        sample_news = [
            {
                'title': 'Microsoft acquires AI startup Lumier for $500 million',
                'content': 'Microsoft Corporation announced today that it has acquired Lumier, an artificial intelligence startup, for approximately $500 million. The acquisition will strengthen Microsoft\'s AI capabilities in the enterprise sector. The deal is expected to close in the next quarter and will see Lumier\'s team joining Microsoft\'s AI research division. Lumier was founded in 2020 and has developed advanced machine learning algorithms for business automation.',
                'url': 'https://example.com/microsoft-lumier',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            },
            {
                'title': 'JPMorgan Chase invests in blockchain company ChainTech',
                'content': 'JPMorgan Chase & Co. has made a strategic investment in ChainTech, a blockchain technology company. The investment is part of JPMorgan\'s ongoing digital transformation initiatives and aims to enhance their blockchain capabilities for cross-border payments and settlement systems. The amount of the investment was not disclosed, but sources close to the deal estimate it to be around $50 million.',
                'url': 'https://example.com/jpmorgan-chaintech',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            },
            {
                'title': 'Google DeepMind partners with pharmaceutical giant',
                'content': 'Google DeepMind has entered into a partnership with Pfizer to develop AI-driven drug discovery platforms. The collaboration will leverage DeepMind\'s AlphaFold technology to accelerate drug development and identify new treatment options for various diseases. This partnership represents a significant step in applying artificial intelligence to pharmaceutical research and development.',
                'url': 'https://example.com/deepmind-pharma',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            },
            {
                'title': 'Apple reports strong quarterly earnings',
                'content': 'Apple Inc. reported better-than-expected quarterly earnings, driven by strong iPhone sales and services growth. The company exceeded analyst expectations with revenue of $89.5 billion, representing 8% year-over-year growth. Services revenue reached an all-time high of $19.5 billion. CEO Tim Cook highlighted the company\'s continued innovation and strong customer loyalty as key drivers of performance.',
                'url': 'https://example.com/apple-earnings',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            },
            {
                'title': 'Amazon launches new AI tools for cloud customers',
                'content': 'Amazon Web Services announced new artificial intelligence tools designed to help businesses build and deploy AI applications more easily. The new services include enhanced machine learning capabilities and improved natural language processing tools for enterprise customers. The launch positions AWS to compete more aggressively in the rapidly growing AI services market against Microsoft Azure and Google Cloud.',
                'url': 'https://example.com/amazon-ai-tools',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            },
            {
                'title': 'Tesla announces new battery technology breakthrough',
                'content': 'Tesla has unveiled a new battery technology that promises to extend electric vehicle range by 30% while reducing costs. The breakthrough in solid-state battery design could significantly impact the electric vehicle market and accelerate the transition to sustainable transportation. Tesla CEO Elon Musk stated that the new batteries will enter production next year.',
                'url': 'https://example.com/tesla-battery',
                'published': datetime.now().isoformat(),
                'source': 'Sample Financial News'
            }
        ]
        return sample_news

    def get_news(self, use_sample_if_empty=True):
        """Main method to get news, with fallback to sample data"""
        print("Starting news collection from financial RSS feeds...")

        # Try RSS feeds first
        articles = self.fetch_news_from_feeds()

        # If no articles from RSS, try API method
        if not articles:
            print("No articles from RSS feeds, trying API sources...")
            articles = self.fetch_financial_news_api()

        # If still no articles and sample is allowed, use sample data
        if not articles and use_sample_if_empty:
            print("Using comprehensive sample financial news data...")
            articles = self.get_sample_financial_news()

        print(f"🎯 Total articles collected: {len(articles)}")
        return articles

# Test the improved scraper
# if __name__ == "__main__":
scraper = NewsScraper()
articles = scraper.get_news(use_sample_if_empty=True)

print(f"\n=== FINAL RESULTS ===")
print(f"Total articles: {len(articles)}")

for i, article in enumerate(articles, 1):
    print(f"\n{i}. {article['title']}")
    print(f"   Source: {article['source']}")
    print(f"   Content: {article['content'][:120]}...")
# Out:
# Starting news collection from financial RSS feeds...
# Attempting to fetch from: https://finance.yahoo.com/news/rssindex
# ✓ Found 48 entries in https://finance.yahoo.com/news/rssindex
#   ✓ Added: 1 Top Growth Stock to Buy and Hold for the Next 10 Years...
#   ✓ Added: Best high-yield savings interest rates today, October 19, 20...
#   ✓ Added: Best money market account rates today, October 19, 2025 (bes...
#   ✓ Added: Best CD rates today, October 19, 2025 (lock in up to 4.25% A...
#   ✓ Added: Mortgage and refinance interest rates today, October 19, 202...
#   ✓ Added: Analyst Report: State Street Corp....
# Attempting to fetch from: https://feeds.finance.yahoo.com/rss/2.0/headline?s=msft,aapl,goog,jpm,gs&region=US&lang=en-US
# ✓ Found 20 entries in https://feeds.finance.yahoo.com/rss/2.0/headline?s=msft,aapl,goog,jpm,gs&region=US&lang=en-US
#   ✓ Added: Apple stock hits all-time high as iPhone 17 sales outpace iP...
#   ✓ Added: Stock market today: Dow, S&P 500, Nasdaq jump amid trade-war...
#   ✓ Added: Will your spending habits change if Rachel Reeves hikes taxe...
#   ✓ Added: Amazon Web Services Outage Disrupts Social Media, Airlines, ...
#   ✓ Added: Exchange-Traded Funds, Equity Futures Higher Pre-Bell Monday...
#   ✓ Added: 5 Things to Know Before the Stock Market Opens...
# Attempting to fetch from: http://feeds.marketwatch.com/marketwatch/topstories/
# Feed returned status 301 for http://feeds.marketwatch.com/marketwatch/topstories/
# Attempting to fetch from: http://feeds.marketwatch.com/marketwatch/marketpulse/
# Feed returned status 301 for http://feeds.marketwatch.com/marketwatch/marketpulse/
# Attempting to fetch from: https://www.investing.com/rss/news_301.rss
# ✓ Found 10 entries in https://www.investing.com/rss/news_301.rss
#   ⚠ Skipped (insufficient content): 21Shares files for Injective ETF, second such product in dev...
#   ⚠ Skipped (insufficient content): Blockchain for Good Alliance and UNDP AltFinLab Launch Block...
#   ⚠ Skipped (insufficient content): Whale.io Introduces Crock Dentist Game and Exclusive RWA NFT...
#   ⚠ Skipped (insufficient content): Limitless Prediction Market Closes $10M Seed Round Ahead of ...
#   ⚠ Skipped (insufficient content): Bybit Web3 Transforms into Bybit Alpha, A One-Click Smart Ga...
#   ⚠ Skipped (insufficient content): Bitcoin price today: rebounds to $110.9k amid easing US-Chin...
# Attempting to fetch from: https://www.investing.com/rss/market_overview.rss
# ✓ Found 10 entries in https://www.investing.com/rss/market_overview.rss
#   ✓ Added: Rare-Earths Arms Race Will Define Global Power and Investmen...
#   ✓ Added: High-Risk Credit Concerns Spark ‘Something’ Moment for Specu...
#   ✓ Added: Will Friday’s Delayed CPI Report Derail the Fed’s Rate Cut P...
#   ✓ Added: The Fed’s Newest Liquidity Backstop in Action...
#   ✓ Added: Liquidity Stress and Hidden Risks: A New Test for the US Ban...
#   ✓ Added: US Dollar and Stocks Bounce Back on Easing Trade Tensions, G...
# Attempting to fetch from: https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000664
# ✓ Found 30 entries in https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000664
#   ✓ Added: Stocks making the biggest moves midday: Apple, Cleveland-Cli...
#   ✓ Added: Activist investor Jana Partners takes stake in medical devic...
#   ✓ Added: Stocks making the biggest moves premarket: Cleveland-Cliffs,...
#   ✓ Added: China’s economy grows 4.8% in third quarter as expected, but...
#   ✓ Added: China wants to play the long game with the U.S. What that me...
#   ✓ Added: This ETF strategy could help risk-averse investors ride out ...
# Attempting to fetch from: https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=15839135
# ✓ Found 30 entries in https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=15839135
#   ✓ Added: Earnings playbook: Netflix and Tesla among the big companies...
#   ✓ Added: What Taiwan Semi's blowout quarter means for these 2 portfol...
#   ✓ Added: TSMC profit surges 39% to beat estimates and hit yet another...
#   ✓ Added: Nestle announces plans to slash 16,000 jobs, stock jumps 9%...
#   ✓ Added: United Airlines' summer earnings and profit outlook top esti...
#   ✓ Added: Salesforce stock jumps after company offers rosy forecast fo...
# Attempting to fetch from: https://feeds.bloomberg.com/markets/news.rss
# ✓ Found 30 entries in https://feeds.bloomberg.com/markets/news.rss
#   ✓ Added: BNP Drops as Sudan Verdict Raises Fear of Costly Settlement...
#   ✓ Added: Oil Holds Losses as Investors Digest Growing Oversupply Evid...
#   ✓ Added: Gold Nears Record as Traders Look Beyond Easing Trade Tensio...
#   ✓ Added: S&amp;P 500 Is Set for Best Two-Day Advance Since June: Mark...
#   ✓ Added: German, Norwegian Ministers Court Canadian Submarine Order W...
#   ✓ Added: Apple Hits First Record of 2025 as iPhone Optimism Fuels Reb...
# Attempting to fetch from: https://www.ft.com/business?format=rss
# Feed returned status 301 for https://www.ft.com/business?format=rss
# Attempting to fetch from: https://feeds.a.dj.com/rss/RSSWSJD.xml
# ✓ Found 20 entries in https://feeds.a.dj.com/rss/RSSWSJD.xml
#   ✓ Added: What to Know About China's DeepSeek AI...
#   ✓ Added: Tech, Media & Telecom Roundup: Market Talk...
#   ✓ Added: Silicon Valley Is Raving About a Made-in-China AI Model...
#   ✓ Added: Reid Hoffman Raises $24.6 Million for AI Cancer-Research Sta...
#   ✓ Added: Can an App Replace a Personal Trainer? I Tested Nearly a Doz...
#   ✓ Added: Bill Gates on His Meeting With Trump, Musk's DOGE, His Child...
# Attempting to fetch from: https://markets.businessinsider.com/rss/news
# ✓ Found 10 entries in https://markets.businessinsider.com/rss/news
#   ✓ Added: One of Wall Street's 'golden' geese is under fire. Here's ho...
#   ✓ Added: Liquidity Services Announces Fourth Quarter Fiscal Year 2025...
#   ✓ Added: AgilityPortal Launches AI-Powered Search to Transform the Di...
#   ✓ Added: Castellum, Inc. to Attend the 2025 Maxim Growth Summit...
#   ✓ Added: Brown & Brown, Inc. names Chief Operating Officer Steve Hear...
#   ✓ Added: Midnight Sun Begins Trading on the OTCQX...
# Successfully processed 9/12 feeds
# 🎯 Total articles collected: 48
#
# === FINAL RESULTS ===
# Total articles: 48
#
# 1. 1 Top Growth Stock to Buy and Hold for the Next 10 Years
#    Source: Yahoo Finance
#    Content: Key Points
#
# ASML's latest quarterly results make it clear that the demand for its advanced chipmaking equipment remains ...
#
# 2. Best high-yield savings interest rates today, October 19, 2025 (Earn up to 4.36% APY)
#    Source: Yahoo Finance
#    Content: Find out how much you could earn with today’s savings rates. Interest rates on savings accounts have been falling, so it...
#
# 3. Best money market account rates today, October 19, 2025 (best account provides 4.26% APY)
#    Source: Yahoo Finance
#    Content: Find out how much you could earn with today’s money market account rates. The Federal Reserve cut its target rate three ...
#
# 4. Best CD rates today, October 19, 2025 (lock in up to 4.25% APY)
#    Source: Yahoo Finance
#    Content: Find out how much you could earn by locking in a high CD rate today. A certificate of deposit (CD) allows you to lock in...
#
# 5. Mortgage and refinance interest rates today, October 19, 2025: Lowest 30-year rate in over 12 months
#    Source: Yahoo Finance
#    Content: The current 30-year fixed mortgage rate has fallen by two basis points to 6.18%. According to Zillow data, this marks it...
#
# 6. Analyst Report: State Street Corp.
#    Source: Yahoo Finance
#    Content: Stephen Biggar
#
# Director of Financial Institutions Research
#
# Stephen is responsible for coverage of large global banks, ...
#
# 7. Apple stock hits all-time high as iPhone 17 sales outpace iPhone 16 in US and China
#    Source: Yahoo Finance
#    Content: Apple's (AAPL) stock price hit an all-time high on Monday, climbing more than 4% after Counterpoint Research published a...
#
# 8. Stock market today: Dow, S&P 500, Nasdaq jump amid trade-war lull, with flurry of earnings on deck
#    Source: Yahoo Finance
#    Content: US stocks stepped higher on Monday as Wall Street kicked off a packed week full of high-profile earnings and a delayed r...
#
# 9. Will your spending habits change if Rachel Reeves hikes taxes?
#    Source: Yahoo Finance
#    Content: As UK budget day edges closer, the persistent chatter about tax hikes is growing ever-louder. Chancellor Rachel Reeves h...
#
# 10. Amazon Web Services Outage Disrupts Social Media, Airlines, Telecom Firms
#    Source: Yahoo Finance
#    Content: Amazon.com's (AMZN) cloud platform, Amazon Web Services, reported a major outage early Monday, disru
#
# Upgrade to read th...
#
# 11. Exchange-Traded Funds, Equity Futures Higher Pre-Bell Monday as Earnings Take Center Stage
#    Source: Yahoo Finance
#    Content: The broad market exchange-traded fund SPDR S&P 500 ETF Trust (SPY) was up 0.3% and the actively trad
#
# Upgrade to read th...
#
# 12. 5 Things to Know Before the Stock Market Opens
#    Source: Yahoo Finance
#    Content: Stock futures are rising this morning as investors await a slew of earnings reports, key inflation data and updates on t...
#
# 13. Rare-Earths Arms Race Will Define Global Power and Investment in 2026
#    Source: Investing.com
#    Content: The global fight for control of rare earths and other critical minerals is intensifying—and it’s set to become one of th...
#
# 14. High-Risk Credit Concerns Spark ‘Something’ Moment for Speculative Investors
#    Source: Investing.com
#    Content: It’s always something. Just when it seemed the stock market had become a one-way street and a sure way to get rich quick...
#
# 15. Will Friday’s Delayed CPI Report Derail the Fed’s Rate Cut Plans?
#    Source: Investing.com
#    Content: Markets continue to price in high odds that the Federal Reserve will cut again next week. The question for Wall Street: ...
#
# 16. The Fed’s Newest Liquidity Backstop in Action
#    Source: Investing.com
#    Content: In July of 2021, after the pandemic and the liquidity issues that arose in 2019, the Fed established a new liquidity bac...
#
# 17. Liquidity Stress and Hidden Risks: A New Test for the US Banking System
#    Source: Investing.com
#    Content: Over the past two weeks, U.S. banks have witnessed rapid developments that unsettled markets and investors, amid signs o...
#
# 18. US Dollar and Stocks Bounce Back on Easing Trade Tensions, Gold Slips
#    Source: Investing.com
#    Content: US and China tone down war of words over trade, seek to defuse latest row
#
# Dollar recovers from lows, equities resume ra...
#
# 19. Stocks making the biggest moves midday: Apple, Cleveland-Cliffs, Oracle, KLA, Tempus AI and more
#    Source: CNBC
#    Content: Check out the companies making the biggest moves midday: Apple — The Tim Cook-led company climbed 4% after the iPhone 17...
#
# 20. Activist investor Jana Partners takes stake in medical device maker Cooper Companies, WSJ says
#    Source: CNBC
#    Content: Shares of Cooper were up 4% in afternoon trading Monday.
#
# Activist investor Jana Partners has taken a stake in medical d...
#
# 21. Stocks making the biggest moves premarket: Cleveland-Cliffs, Liberty Energy, Hologic & more
#    Source: CNBC
#    Content: Check out the companies making headlines before the bell. Cleveland-Cliffs — Shares jumped 10.5% after the steel company...
#
# 22. China’s economy grows 4.8% in third quarter as expected, but investment sees 'rare and alarming' drop
#    Source: CNBC
#    Content: China Shipping containers are seen at the port of Oakland as trade tensions continue over U.S. tariffs with China, in Oa...
#
# 23. China wants to play the long game with the U.S. What that means for Chinese stocks
#    Source: CNBC
#    Content: As U.S.-China tensions escalate and overall market volatility rises, investment strategists expect Chinese stocks will h...
#
# 24. This ETF strategy could help risk-averse investors ride out wild market swings
#    Source: CNBC
#    Content: The CBOE Volatility Index , otherwise known as the Wall Street's fear gauge, is coming off its most volatile week since ...
#
# 25. Earnings playbook: Netflix and Tesla among the big companies slated to report
#    Source: CNBC
#    Content: The third-quarter earnings season has gotten off to a strong start. Investors will look to this week's batch of companie...
#
# 26. What Taiwan Semi's blowout quarter means for these 2 portfolio chip stocks
#    Source: CNBC
#    Content: Every weekday the CNBC Investing Club with Jim Cramer holds a "Morning Meeting" livestream at 10:20 a.m. ET. Here's a re...
#
# 27. TSMC profit surges 39% to beat estimates and hit yet another record on AI chip demand
#    Source: CNBC
#    Content: The TSMC logo is displayed on a building in Hsinchu, Taiwan April 15, 2025.
#
# Taiwan Semiconductor Manufacturing Co. on T...
#
# 28. Nestle announces plans to slash 16,000 jobs, stock jumps 9%
#    Source: CNBC
#    Content: KitKat chocolate bars, manufactured by Nestle SA, arranged in London, U.K., on Monday, July 26, 2021. Nestle report thei...
#
# 29. United Airlines' summer earnings and profit outlook top estimates, but revenue falls short
#    Source: CNBC
#    Content: United Airlines on Wednesday forecast higher-than-expected earnings for the fourth quarter after a rocky start to 2025.
# ...
#
# 30. Salesforce stock jumps after company offers rosy forecast for 2030
#    Source: CNBC
#    Content: Marc Benioff, chief executive officer of Salesforce Inc., speaks during the 2025 Dreamforce conference in San Francisco,...
#
# 31. BNP Drops as Sudan Verdict Raises Fear of Costly Settlement
#    Source: Bloomberg
#    Content: BNP Paribas SA plummeted after a court ruling linked it to human rights abuses in Sudan, triggering speculation the firm...
#
# 32. Oil Holds Losses as Investors Digest Growing Oversupply Evidence
#    Source: Bloomberg
#    Content: Oil edged down slightly amid signs of easing tensions between the US and China, while traders took stock of mounting evi...
#
# 33. Gold Nears Record as Traders Look Beyond Easing Trade Tensions
#    Source: Bloomberg
#    Content: Gold advanced to trade near its record as investors piled into the precious metal despite easing trade tensions and the ...
#
# 34. S&amp;P 500 Is Set for Best Two-Day Advance Since June: Markets Wrap
#    Source: Bloomberg
#    Content: Wall Street traders drove stocks higher amid solid results from Corporate America while tariff tensions between the worl...
#
# 35. German, Norwegian Ministers Court Canadian Submarine Order Worth Billions
#    Source: Bloomberg
#    Content: Germany and Norway’s defense ministers are meeting their Canadian counterpart Monday to push for Thyssenkrupp Marine Sys...
#
# 36. Apple Hits First Record of 2025 as iPhone Optimism Fuels Rebound
#    Source: Bloomberg
#    Content: Apple Inc. shares hit their first record of 2025 after Loop Capital upgraded the stock to buy from hold, citing positive...
#
# 37. What to Know About China's DeepSeek AI
#    Source: Wall Street Journal
#    Content: The Chinese upstart says it has trained high-performing AI models cheaply, without using the most advanced chips....
#
# 38. Tech, Media & Telecom Roundup: Market Talk
#    Source: Wall Street Journal
#    Content: DeepSeek, SoFi and more in the latest Market Talks covering Technology, Media and Telecom....
#
# 39. Silicon Valley Is Raving About a Made-in-China AI Model
#    Source: Wall Street Journal
#    Content: DeepSeek is called “amazing and impressive” despite working with less-advanced chips....
#
# 40. Reid Hoffman Raises $24.6 Million for AI Cancer-Research Startup
#    Source: Wall Street Journal
#    Content: The LinkedIn co-founder is starting Manas AI with “The Emperor of All Maladies” author Siddhartha Mukherjee....
#
# 41. Can an App Replace a Personal Trainer? I Tested Nearly a Dozen to Find Out
#    Source: Wall Street Journal
#    Content: Apps can add flexibility and freshness to your routine. Just try not to get injured....
#
# 42. Bill Gates on His Meeting With Trump, Musk's DOGE, His Childhood
#    Source: Wall Street Journal
#    Content: The billionaire spoke with The Wall Street Journal ahead of his coming book, “Source Code.”...
#
# 43. One of Wall Street's 'golden' geese is under fire. Here's how worried you should be about private credit.
#    Source: Business Insider
#    Content: Good morning and welcome to the inaugural edition of First Trade. I'm thrilled you're here. Are you still banking on the...
#
# 44. Liquidity Services Announces Fourth Quarter Fiscal Year 2025 Earnings Conference Call
#    Source: Business Insider
#    Content: BETHESDA, Md., Oct. 20, 2025 (GLOBE NEWSWIRE) -- Liquidity Services (NASDAQ:LQDT), a leading global commerce company pow...
#
# 45. AgilityPortal Launches AI-Powered Search to Transform the Digital Workplace Experience
#    Source: Business Insider
#    Content: The new intelligent search experience helps employees instantly find answers, improve productivity, and make work smarte...
#
# 46. Castellum, Inc. to Attend the 2025 Maxim Growth Summit
#    Source: Business Insider
#    Content: VIENNA, Va., Oct. 20, 2025 (GLOBE NEWSWIRE) -- Castellum, Inc. (NYSE-American: CTM) (“Castellum” or “CTM”), a cybersecur...
#
# 47. Brown & Brown, Inc. names Chief Operating Officer Steve Hearn president of Retail segment
#    Source: Business Insider
#    Content: DAYTONA BEACH, Fla., Oct. 20, 2025 (GLOBE NEWSWIRE) -- Brown & Brown, Inc. (NYSE: BRO) (“the Company”) announced today t...
#
# 48. Midnight Sun Begins Trading on the OTCQX
#    Source: Business Insider
#    Content: Midnight Sun Shares Now Trading on the OTCQX Best Market in the United States under the symbol "MDNGF."
#
# Vancouver, Brit...

# %%
df = pd.DataFrame(articles)
df.head()
# Out:
#                                                title  \
# 0  1 Top Growth Stock to Buy and Hold for the Nex...
# 1  Best high-yield savings interest rates today, ...
# 2  Best money market account rates today, October...
# 3  Best CD rates today, October 19, 2025 (lock in...
# 4  Mortgage and refinance interest rates today, O...
#
#                                                  url             published  \
# 0  https://finance.yahoo.com/news/1-top-growth-st...  2025-10-19T10:15:00Z
# 1  https://finance.yahoo.com/personal-finance/art...  2025-10-19T10:00:34Z
# 2  https://finance.yahoo.com/personal-finance/ban...  2025-10-19T10:00:40Z
# 3  https://finance.yahoo.com/personal-finance/ban...  2025-10-19T10:00:51Z
# 4  https://finance.yahoo.com/personal-finance/mor...  2025-10-19T10:00:23Z
#
#           source                                            content summary
# 0  Yahoo Finance  Key Points\n\nASML's latest quarterly results ...
# 1  Yahoo Finance  Find out how much you could earn with today’s ...
# 2  Yahoo Finance  Find out how much you could earn with today’s ...
# 3  Yahoo Finance  Find out how much you could earn by locking in...
# 4  Yahoo Finance  The current 30-year fixed mortgage rate has fa...

# %%
df.shape
# Out:
# (48, 6)

# %%
df.isna().sum()
# Out:
# title        0
# url          0
# published    0
# source       0
# content      0
# summary      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['source'].value_counts()
# Out:
# source
# Yahoo Finance          12
# CNBC                   12
# Investing.com           6
# Bloomberg               6
# Wall Street Journal     6
# Business Insider        6
# Name: count, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/My Drive/MLOps/news_alert/news.csv',index=False)
